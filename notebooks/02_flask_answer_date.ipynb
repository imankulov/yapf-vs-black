# %%
import sys
import os
sys.path.insert(1, os.path.dirname(os.getcwd()))
from versus import *

# %%
yapf_df = ultimate_answer_by_date(flask, yapf, 60)
yapf_df = yapf_df[yapf_df.date > '2018-01-01']

# %%
yapf_df.plot.bar(x='date', y=['lines_deleted', 'lines_added'], stacked=True, 
                 title='Diff size for yapf formatter (applied every 2 months)')

# %%
black_df = ultimate_answer_by_date(flask, black, 60)
black_df = black_df[black_df.date > '2018-01-01']

# %%
black_df.plot.bar(x='date', y=['lines_deleted', 'lines_added'], stacked=True,  
                 title='Diff size for Black formatter (applied every 2 months)')

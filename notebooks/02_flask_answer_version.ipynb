# %%
import sys
import os
sys.path.insert(1, os.path.dirname(os.getcwd()))
from versus import *

# %%
flask_yapf = ultimate_answer_by_version(flask, yapf)
flask_yapf = flask_yapf[flask_yapf.date > '2018-01-01']

# %%
flask_black = ultimate_answer_by_version(flask, black)
flask_black = flask_black[flask_black.date > '2018-01-01']

# %%
flask_yapf.plot.bar(x='version', y=['lines_deleted', 'lines_added'], stacked=True, 
                    title='Diff size for yapf formatters')

# %%
flask_black.plot.bar(x='version', y=['lines_deleted', 'lines_added'], stacked=True, title='Diff size for Black formatters')
